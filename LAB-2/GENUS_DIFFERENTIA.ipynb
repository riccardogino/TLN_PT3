# %%
import nltk
from nltk.corpus import wordnet as wn
import json
import polars as pl
from itertools import product
from collections import Counter

# Download WordNet data
nltk.download('wordnet')

import sys
sys.path.append('..')
from utils import utils as u

# %% [markdown]
# ## LOAD DEFINITIONS

# %%
df = json.loads(pl.read_csv("../datasets/TLN-definitions-23.tsv", separator='\t').write_json())

data = {}

# %% [markdown]
# ## SAVE AND STORE DATA

# %%
for col in df['columns']:
    if col['name'] != '1':
        data[col['name']] = {}
        count = 1
        for v in col['values']:
            data[col['name']][count] = u.noise_reduction_en(v)
            count += 1

# %% [markdown]
# ## RICERCA GENUS

# %%
def search_genus(definitions,number_of_genus):
    #print(definitions)
    words=[]
    final_genus=[]
    for key in definitions.keys():
        for word in definitions[key]:
            words.append(word)
    
    genus_frequency = Counter(words)
    firsts_genus= (genus_frequency.most_common(1))
    print(firsts_genus)
    for tupla in firsts_genus:
        final_genus.append(tupla[0])
    return final_genus

# %% [markdown]
# ## RICERCA DEGLI IPONIMI

# %%
def search_hyponyms(genus_words):
    genus_synsets= []
    genus_hyponyms = []
    for genus in genus_words:
        for syn in wn.synsets(genus):
            genus_synsets.append(syn)
    for syn in genus_synsets:
        for hyp in syn.hyponyms():
            genus_hyponyms.append(hyp)
    return genus_hyponyms

# %% [markdown]
# ## RICERCA DEFINIZIONI DEI GENUS

# %%
def search_hyponyms_definitions(genus_hyponyms):
    genus_definitions={}
    for hyp in genus_hyponyms:
        definits = hyp.definition()
        genus_definitions[hyp] = nltk.word_tokenize(definits)
    return genus_definitions

# %% [markdown]
# ## RICERCA PAROLA TARGET

# %%
def search_target(def_document,genus_definitions):
    overlap_max=0
    target=""
    for key in genus_definitions.keys():
    
        overlap = len(set(def_document).intersection(set(genus_definitions[key])))
       
        if overlap > overlap_max:
            overlap_max = overlap
            target=key
    return target

# %% [markdown]
# ## MAIN CON STAMPA DEL RISULTATO

# %%
cand_dict={}
synset_definition = []
number_of_genus = 10
for word in data:
    
     #A LIVELLO DI DEFINIZIONI
    genus_words= search_genus(data[word],number_of_genus)
        
    genus_hyponyms= search_hyponyms(genus_words)
        
    genus_hyponyms_definitions= search_hyponyms_definitions(genus_hyponyms)
    
    definitions_document = data[word]
    print("----------------",word,"----------------")
    for key in definitions_document.keys():
        print(genus_words)
        target_word= search_target(definitions_document[key],genus_hyponyms_definitions)
        print("---------------------------------------------------------")
        print("DEFINIZIONE")
        print(definitions_document[key],'\n')
        print("PAROLA TARGET")
        if type(target_word) != str:
            print(target_word.lemmas()[0].name())
# Out:
# [('room', 14)]
# ---------------- door ----------------
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['construction', 'use', 'divide', 'two', 'room', 'temporarily', 'close', 'passage']
#
# PAROLA TARGET
# cloakroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['opening', 'open', 'close']
#
# PAROLA TARGET
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['object', 'divide', 'two', 'room', 'close', 'hole', 'wall', 'open', 'door', 'let', 'people', 'enter', 'get']
#
# PAROLA TARGET
# door
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Usable', 'access', 'one', 'area', 'another']
#
# PAROLA TARGET
# anteroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Structure', 'delimit', 'area', 'allow', 'access']
#
# PAROLA TARGET
# anteroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['object', 'use', 'block', 'passage', 'move', 'pass']
#
# PAROLA TARGET
# headroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['assembled', 'object', 'historically', 'make', 'wood', 'also', 'iron', 'material', 'use', 'separate', 'room', 'building', 'Sometimes', 'open', 'move', 'handle', 'push', 'lock', 'require', 'mean', 'unlock', 'consist', 'main', 'body', 'hinge', 'rotate', 'lock']
#
# PAROLA TARGET
# compartment
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['object', 'use', 'go', 'room', 'separate', 'wall', 'open', 'close']
#
# PAROLA TARGET
# compartment
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['something', 'open', 'order', 'access', 'another', 'place']
#
# PAROLA TARGET
# classroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['access', 'room']
#
# PAROLA TARGET
# anteroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['object', 'allow', 'access', 'room']
#
# PAROLA TARGET
# anteroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Enclosing', 'entrance', 'block', 'intruder', 'well', 'weather', 'condition', 'usually', 'lock', 'key', 'sort', 'time', 'present', 'small', 'opening', 'one', 'see', 'outside']
#
# PAROLA TARGET
# walk-in
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['object', 'allow', 'people', 'get', 'inside', 'outside', 'chamber', 'Usually', 'make', 'mechanism', 'enable', 'key', 'lock', 'unlock']
#
# PAROLA TARGET
# anechoic_chamber
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['wall', 'open', 'close']
#
# PAROLA TARGET
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['barrier', 'mechanism', 'block', 'allow', 'access', 'room']
#
# PAROLA TARGET
# anteroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['way', 'let', 'people', 'enter', 'exit', 'room']
#
# PAROLA TARGET
# living_room
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Artificial', 'object', 'usually', 'make', 'hinge', 'main', 'body', 'handle', 'allow', 'passage', 'two', 'space', 'open']
#
# PAROLA TARGET
# headroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['object', 'open', 'close', 'allow', 'enter', 'exit', 'place']
#
# PAROLA TARGET
# classroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Element', 'room', 'allow', 'block', 'passage', 'wall']
#
# PAROLA TARGET
# headroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['object', 'cross', 'access', 'limited', 'place']
#
# PAROLA TARGET
# classroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['rectangular', 'object', 'usually', 'make', 'wood', 'use', 'lock', 'access', 'room', 'house']
#
# PAROLA TARGET
# back_room
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Entrance', 'exit', 'space', 'building', 'room']
#
# PAROLA TARGET
# furnace_room
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['object', 'allow', 'connection', 'two', 'space']
#
# PAROLA TARGET
# headroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['architecture', 'make', 'person', 'pas', 'new', 'space', 'leave', 'another', 'one']
#
# PAROLA TARGET
# presence_chamber
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['entance', 'building', 'room']
#
# PAROLA TARGET
# furnace_room
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['object', 'open', 'close', 'entrance', 'room']
#
# PAROLA TARGET
# anteroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Object', 'lock', 'entrance', 'house']
#
# PAROLA TARGET
# anteroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['point', 'access', 'space', 'Physically', 'object', 'block', 'access', 'room', 'space']
#
# PAROLA TARGET
# anteroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['open', 'allow', 'something', 'go']
#
# PAROLA TARGET
# headroom
# ['room']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Auxiliary', 'structure', 'build', 'blank', 'space', 'wall', 'use', 'access', 'different', 'area', 'building']
#
# PAROLA TARGET
# anteroom
# [('insect', 28)]
# ---------------- ladybug ----------------
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'fly', 'insect', 'typically', 'red', 'black', 'spot', 'six', 'leg']
#
# PAROLA TARGET
# psocopterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['insect', 'wing', 'red', 'black', 'dot', 'many', 'culture', 'symbol', 'good', 'luck']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['insect', 'fly', 'red', 'orange', 'color', 'black', 'dot']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Small', 'insect', 'red', 'back']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Small', 'round', 'fly', 'insect']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'fly', 'insect', 'beatle', 'family', 'tendentially', 'color', 'red']
#
# PAROLA TARGET
# leaf_miner
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Small', 'insect', 'insectivore', 'use', 'natural', 'pest', 'control', 'Red', 'black', 'dot', 'back', 'black', 'head', 'Flies', 'consider', 'bring', 'luck']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'red', 'insect', 'black', 'dot', 'bring', 'luck', 'culture']
#
# PAROLA TARGET
# psocopterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'insect', 'red', 'black', 'dot']
#
# PAROLA TARGET
# psocopterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'insect', 'red', 'yellow', 'dot', 'coat']
#
# PAROLA TARGET
# psocopterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'fly', 'insect', 'usually', 'red', 'black', 'dot']
#
# PAROLA TARGET
# dipterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Tiny', 'fly', 'insect', 'characterise', 'red', 'coat', 'Usually', 'consider', 'good', 'omen']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'red', 'insect', 'black', 'spot', 'live', 'planet', 'usually', 'associate', 'good', 'luck', 'fall', 'human']
#
# PAROLA TARGET
# dipterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'red', 'insect', 'black', 'dot']
#
# PAROLA TARGET
# psocopterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['red', 'insect', 'black', 'spot']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['insect', 'black', 'small', 'dot', 'back']
#
# PAROLA TARGET
# psocopterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Harmless', 'fly', 'insect', 'characterize', 'black', 'dot', 'red', 'wing', 'Generally', 'associate', 'good', 'luck']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'fly', 'insect', 'characterize', 'red', 'color', 'black', 'spot', 'say', 'bring', 'good', 'luck']
#
# PAROLA TARGET
# psocopterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Small', 'round', 'insect', 'usually', 'red', 'black', 'dot', 'Generally', 'link', 'good', 'luck']
#
# PAROLA TARGET
# louse
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Small', 'insect', 'characterize', 'red', 'color', 'black', 'dot']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'round', 'insect', 'usually', 'red', 'black', 'dot', 'fly', 'flower']
#
# PAROLA TARGET
# dipterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Red', 'small', 'bug', 'black', 'spot', 'round', 'shape']
#
# PAROLA TARGET
# dipterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'insect', 'usually', 'characterize', 'red', 'color', 'black', 'dot']
#
# PAROLA TARGET
# dipterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['insect', 'fly', 'wich', 'brings', 'luck', 'person']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'red', 'insect', 'black', 'dot']
#
# PAROLA TARGET
# psocopterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['insect', 'red', 'back']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Red', 'insect', 'black', 'dot', 'back']
#
# PAROLA TARGET
# beetle
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['small', 'insect', 'know', 'red', 'wing', 'black', 'dot']
#
# PAROLA TARGET
# psocopterous_insect
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['bug', 'colored', 'dot']
#
# PAROLA TARGET
# ['insect']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Flying', 'structured', 'insect', 'usually', 'red', 'color', 'pattern']
#
# PAROLA TARGET
# louse
# [('physical', 14)]
# ---------------- pain ----------------
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['feeling', 'physical', 'mental', 'distress']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['feeling', 'physical', 'emotional', 'bad', 'hurt']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['felling', 'couscious', 'experince', 'suffer']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Concept', 'describe', 'suffering', 'living']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Feeling', 'physical', 'discomfort']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['unpleasant', 'burning', 'sensation']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['negative', 'sensation', 'felt', 'creature', 'physical', 'nature', 'body', 'damage', 'psychological']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['feeling', 'physical', 'pain', 'cause', 'injury', 'emotional', 'pain', 'cause', 'sadness']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['sentiment', 'express', 'sorrow']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['unpleasant', 'sensation', 'result', 'physical', 'emotional', 'exertion']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['unpleasant', 'physical', 'emotional', 'sensation']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Feeling', 'occur', 'something', 'bad', 'happen', 'either', 'phisically', 'mentally', 'could', 'result', 'light', 'discomfort', 'loud', 'cry']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['physical', 'emotional', 'sensation', 'bring', 'discomfort', 'soreness', 'person']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['feeling', 'cause', 'physical', 'emotional', 'harm']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['unpleasant', 'harmful', 'feeling']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['physical', 'emotional', 'sensation', 'unconfortable']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Feeling', 'uneasiness', 'cause', 'physical', 'emotional', 'harm']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['feeling', 'feel', 'tangible', 'situation']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Feeling', 'produce', 'natural', 'complex', 'brain', 'necessary', 'make', 'creature', 'aware', 'physical', 'issue']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['unpleasant', 'emotion', 'associate', 'suffering']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['emotion', 'felt', 'get', 'harm', 'body', 'want', 'tell', 'u', 'something', 'right']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Kind', 'physical', 'emotional', 'sensation', 'felt', 'response', 'something', 'harmful', 'emotionally', 'damaging']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['feeling', 'cause', 'discomfort', 'experience']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Something', 'hurt', 'person', 'emotionally', 'physically']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['sicken', 'sensation']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['bad', 'physical', 'emotional', 'feeling']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Feeling', 'get', 'hurt']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['sensation', 'hurt']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['bad', 'feeling']
#
# PAROLA TARGET
# ['physical']
# ---------------------------------------------------------
# DEFINIZIONE
# ['negative', 'sensation', 'cause', 'discomfort', 'physically', 'mentally']
#
# PAROLA TARGET
# [('see', 8)]
# ---------------- blurriness ----------------
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['sight', 'focus']
#
# PAROLA TARGET
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['absence', 'definite', 'border', 'shapelessness']
#
# PAROLA TARGET
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['sensation', 'felt', 'ca', 'see', 'clearly', 'border', 'something']
#
# PAROLA TARGET
# catch_sight
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Lack', 'sharpness']
#
# PAROLA TARGET
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Characteristic', 'lack', 'clarity', 'precision']
#
# PAROLA TARGET
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['sensation', 'blur', 'eye', 'see', 'everything', 'blur']
#
# PAROLA TARGET
# see
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['inability', 'accurately', 'perceive', 'certain', 'kind', 'goal', 'whether', 'physical', 'conceptual']
#
# PAROLA TARGET
# card
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['lack', 'memory', 'bad', 'eye', 'vision', 'unfocused', 'image']
#
# PAROLA TARGET
# see
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['condition', 'thant', 'make', 'see', 'totally', 'bright', 'clear']
#
# PAROLA TARGET
# behold
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['state', 'confusion', 'result', 'physical', 'exertion', 'use', 'alcohol', 'drug']
#
# PAROLA TARGET
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['sense', 'confusion']
#
# PAROLA TARGET
# spiritualize
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Property', 'object', 'hard', 'make', 'see', 'usually', 'happen', 'drug', 'use', 'illness', 'Also', 'propery', 'photograph', 'focus']
#
# PAROLA TARGET
# behold
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['condition', 'allow', 'person', 'see', 'detailed', 'way', 'people', 'object', 'close', 'far', 'distance']
#
# PAROLA TARGET
# behold
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['absence', 'clarity', 'define', 'border', 'image', 'visual']
#
# PAROLA TARGET
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['visual', 'condition', 'blend', 'detail', 'together', 'lose', 'clarity']
#
# PAROLA TARGET
# peruse
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['phenomenon', 'disrupt', 'partially', 'vision', 'person', 'camera']
#
# PAROLA TARGET
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['State', 'indefiniteness', 'state', 'something', 'perceive', 'perceive', 'clearly', 'metaphorically', 'state', 'ill', 'define', 'concept']
#
# PAROLA TARGET
# catch_sight
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['specific', 'condition', 'make', 'something', 'less', 'visible', 'Often', 'use', 'photographic', 'context', 'subject', 'focus']
#
# PAROLA TARGET
# catch_sight
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['State', 'attribute', 'image', 'natural', 'eye', 'vision', 'device', 'border', 'clearly', 'define']
#
# PAROLA TARGET
# see
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['characteristic', 'undefined', 'image', 'whose', 'shape', 'line', 'hard', 'recognize']
#
# PAROLA TARGET
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['phenomenon', 'happen', 'something', 'visually', 'clear', 'colour', 'mix', 'near', 'edge', 'happen', 'picture', 'visual', 'problem', 'eye']
#
# PAROLA TARGET
# catch_sight
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['effect', 'affect', 'vision', 'image', 'confuse', 'outline', 'detail', 'make', 'hard', 'see']
#
# PAROLA TARGET
# behold
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['visual', 'effect', 'make', 'clear', 'hard', 'see', 'something']
#
# PAROLA TARGET
# catch_sight
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['visual', 'effect', 'allow', 'see', 'clear', 'way', 'object']
#
# PAROLA TARGET
# behold
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['visual', 'perception', 'confuse', 'look']
#
# PAROLA TARGET
# tend
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['distorted', 'vision']
#
# PAROLA TARGET
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Condition', 'eye', 'correct', 'eyeglass']
#
# PAROLA TARGET
# see
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['faulty', 'perception', 'specific', 'object', 'perceive', 'properly', 'define']
#
# PAROLA TARGET
# abstract
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['blind', 'effect', 'increase', 'distance']
#
# PAROLA TARGET
# ['see']
# ---------------------------------------------------------
# DEFINIZIONE
# ['Lack', 'texture', 'quality', 'image', 'give', 'low', 'focus']
#
# PAROLA TARGET
# reconsider
