# %% [markdown]
# ## Consegna
# Si richiede un'implementazione di un esercizio di Topic Modeling, utilizzando librerie open (come ad es. GenSim (https://radimrehurek.com/gensim/). Si richiede l'utilizzo di un corpus di almeno 1k documenti. Testare un algoritmo (ad esempio LDA) con più valori di k (num. di topics) e valutare la coerenza dei risultati, attraverso fine-tuning su parametri e pre-processing. Update: essendo che spesso i topic, per essere interpretabili, devono contenere content words, potete pensare di filtrare solamente i sostantivi in fase di preprocessing (cioè POS=noun).

# %% [markdown]
# ## Import

# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import gensim
import nltk
from nltk.corpus import reuters
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from pprint import pprint
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Scarica il dataset "reuters" se non è già stato scaricato
nltk.download('reuters')

# Ottiene l'elenco dei file nel dataset
file_ids = reuters.fileids()
documents = []

for i in range(0,len(file_ids)):
    documents.append(reuters.raw(file_ids[i]))
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     /Users/rossellaborra/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!

# %% [markdown]
# ## Estrazione sostantivi e pulizia del corpus

# %%
# Estrai i sostantivi dai documenti e crea il corpus
stop_words = set(stopwords.words('english'))
corpus = []
for document in documents:
    words = word_tokenize(document)
    words = [word.lower() for word in words if word.isalpha()
             and word.lower() not in stop_words]
    tagged_words = pos_tag(words)
    nouns = [word for word, pos in tagged_words if pos == 'NN']
    corpus.append(nouns)

# %%
for i in range(0,10):
    print(corpus[i])
# Out:
# ['damage', 'rift', 'trade', 'friction', 'japan', 'row', 'damage', 'reuter', 'japan', 'lead', 'conflict', 'loss', 'retaliation', 'japan', 'failure', 'stick', 'pact', 'world', 'business', 'spokesman', 'co', 'ltd', 'lt', 'length', 'time', 'erosion', 'murtha', 'stock', 'analyst', 'tokyo', 'office', 'broker', 'seriousness', 'threat', 'japan', 'trade', 'official', 'trade', 'trade', 'surplus', 'dlrs', 'year', 'pct', 'surplus', 'exchange', 'world', 'trade', 'defuse', 'retaliation', 'paul', 'sheen', 'chairman', 'textile', 'group', 'official', 'trade', 'promotion', 'association', 'trade', 'dispute', 'japan', 'pressure', 'korea', 'japan', 'year', 'trade', 'surplus', 'dlrs', 'malaysia', 'trade', 'japan', 'japan', 'selling', 'share', 'view', 'advantage', 'pressure', 'block', 'view', 'lawrence', 'industry', 'prevent', 'day', 'hong', 'kong', 'action', 'trade', 'year', 'export', 'market', 'government', 'trade', 'interest', 'concern', 'industry', 'minister', 'john', 'button', 'canberra', 'kind', 'deterioration', 'trade', 'matter', 'button', 'coal', 'beef', 'japan', 'country', 'trade', 'japan', 'ruling', 'party', 'yesterday', 'economy', 'budget', 'record', 'public', 'year', 'spending', 'emergency', 'measure', 'economy', 'minister', 'yasuhiro', 'nakasone', 'reform', 'program', 'deputy', 'trade', 'representative', 'michael', 'makoto', 'kuroda', 'japan', 'deputy', 'minister', 'trade', 'industry', 'week', 'effort', 'end', 'dispute']
# ['vermin', 'eat', 'pct', 'grain', 'survey', 'year', 'mln', 'fruit', 'output', 'mln', 'paper', 'waste', 'storage', 'preservation', 'government', 'programme', 'waste', 'technology', 'storage', 'preservation', 'production', 'paper']
# ['japan', 'energy', 'demand', 'trade', 'industry', 'energy', 'outlook', 'meet', 'forecast', 'energy', 'demand', 'ministry', 'projection', 'energy', 'year', 'mln', 'mln', 'decision', 'industry', 'rise', 'value', 'yen', 'decline', 'power', 'demand', 'miti', 'planning', 'work', 'energy', 'outlook', 'committee', 'agency', 'energy', 'energy', 'supply', 'oil', 'coal', 'gas', 'energy', 'bulk', 'japan', 'power', 'year', 'march', 'basis', 'oil', 'pct', 'gas', 'pct']
# ['thai', 'trade', 'deficit', 'quarter', 'thailand', 'trade', 'deficit', 'quarter', 'year', 'business', 'department', 'thailand', 'business', 'climate', 'year', 'increase', 'country', 'oil', 'import', 'bill', 'quarter', 'oil', 'department', 'quarter', 'export', 'growth', 'rice', 'pct', 'sugar', 'pct', 'tin', 'pct', 'pct', 'export', 'growth', 'jewellery', 'pct', 'clothing', 'rubber', 'pct']
# ['indonesia', 'price', 'oil', 'cpo', 'tonne', 'fob', 'year', 'demand', 'fall', 'output', 'hasrul', 'harahap', 'minister', 'tree', 'sumatran', 'cpo', 'tonne', 'cif', 'delivery', 'rotterdam', 'harahap', 'indonesia', 'palm', 'oil', 'malaysia', 'market', 'share', 'world', 'producer', 'palm', 'oil', 'malaysia', 'palm', 'oil', 'month', 'ramadan', 'harahap', 'import', 'cover', 'shortage', 'export', 'calendar', 'bank']
# ['ban', 'yesterday', 'dispute', 'shipping', 'ban', 'week', 'pay', 'claim', 'movement', 'port', 'pay', 'dispute', 'arbitration', 'commission', 'today', 'disruption', 'today', 'cargo', 'sydney', 'port', 'kembla', 'action', 'nsw', 'part', 'week', 'action', 'council', 'protest', 'state', 'compensation', 'port', 'turn', 'work', 'time', 'shift', 'walk', 'cargo', 'container', 'disruption', 'effect', 'shipping']
# ['commodity', 'exchange', 'commodity', 'exchange', 'trading', 'commodity', 'calendar', 'exchange', 'chairman', 'nainggolan', 'telephone', 'interview', 'trading', 'palm', 'oil', 'sawn', 'pepper', 'tobacco', 'trading', 'palm', 'oil', 'cpo', 'oil', 'question', 'trade', 'minister', 'saleh', 'decision', 'exchange', 'coffee', 'rubber', 'outcry', 'system', 'week', 'move', 'mistake', 'confidence', 'exchange', 'rubber', 'trading', 'coffee', 'rubber', 'coffee', 'prompt', 'delivery', 'exchange', 'trade', 'ministry', 'exchange', 'board', 'introduction', 'trading', 'official', 'feasibility', 'study', 'trade', 'minister', 'saleh', 'world', 'producer', 'rubber', 'expand', 'rubber', 'marketing', 'effort', 'development', 'exchange', 'nainggolan', 'exchange', 'boost', 'interest', 'building', 'encourage', 'use', 'exchange', 'delegation', 'europe', 'mexico', 'participation', 'exchange', 'start', 'trading', 'coffee', 'trading', 'april', 'rupiah', 'rubber', 'exchange', 'report', 'coffee', 'calendar', 'membership', 'exchange']
# ['sri', 'lanka', 'approval', 'wheat', 'price', 'food', 'department', 'department', 'agriculture', 'grain', 'sale', 'wheat', 'dlrs', 'tonne', 'c', 'f', 'pacific', 'colombo', 'april', 'delivery']
# ['mining', 'gold', 'mine', 'corp', 'wmc', 'venture', 'gold', 'mine', 'territory', 'cost', 'mln', 'dlrs', 'mine', 'goodall', 'project', 'wmc', 'pct', 'grace', 'co', 'unit', 'river', 'mt', 'bundey', 'wmc', 'statement', 'leach', 'treatment', 'plant', 'produce', 'gold', 'year', 'production', 'ore', 'capacity']
# ['sumitomo', 'bank', 'recovery', 'merger', 'bank', 'ltd', 'status', 'japan', 'bank', 'result', 'merger', 'heiwa', 'bank', 'heiwa', 'sogo', 'bank', 'president', 'koh', 'bank', 'position', 'position', 'place', 'interview', 'merger', 'profitability', 'efficiency', 'sumitomo', 'branch', 'network', 'area', 'pay', 'sumitomo', 'sogo', 'view', 'bank', 'merger', 'cost', 'branch', 'network', 'scratch', 'bank', 'business', 'competition', 'wisdom', 'everything', 'place', 'kleinwort', 'benson', 'analyst', 'simon', 'smithson', 'business', 'share', 'investment', 'bank', 'sumitomo', 'pay', 'mln', 'dlrs', 'pct', 'partnership', 'bank', 'time', 'reserve', 'board', 'exchange', 'increase', 'business', 'duck', 'sumitomo', 'analyst', 'komatsu', 'pay', 'time', 'century', 'komatsu', 'komatsu', 'patient', 'business', 'home', 'article', 'exchange', 'act', 'version', 'act', 'investment', 'deregulation', 'business', 'komatsu', 'bank', 'kind', 'deregulation', 'focus', 'business', 'government', 'bond', 'pct', 'share', 'sumitomo', 'business', 'bank', 'subsidiary', 'banca', 'del', 'gottardo', 'finance', 'ministry', 'decision', 'parent', 'komatsu', 'push', 'decision', 'gottardo', 'subsidiary', 'make', 'city', 'expand', 'lending', 'medium', 'demand', 'business', 'devote', 'lot', 'time', 'merger', 'heiwa', 'sogo', 'sumitomo', 'question', 'decade', 'strategy']

# %% [markdown]
# ## stampa word cloud per frequenza parole

# %%
# Import the wordcloud library

# Join the different processed titles together.
#long_string = ','.join(list(papers['paper_text_processed'].values))
delimiter = ','
corpus_string = ""

all_words = [word for sentence in corpus for word in sentence]

corpus_string = delimiter.join(all_words)
# Convertire tutte le parole in minuscolo
corpus_string = corpus_string.lower()


# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')
# Generate a word cloud

# Generate a word cloud
wordcloud.generate(corpus_string)
# Visualize the word cloud


# Visualize the word cloud
wordcloud.to_image()
# Out:
# /Users/rossellaborra/lib/python3.8/site-packages/wordcloud/wordcloud.py:106: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   self.colormap = plt.cm.get_cmap(colormap)
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# ## Creazione del dizionario e del corpus in formato bag-of-words

# %%
dictionary = Dictionary(corpus) ##id2word
corpus_bow = [dictionary.doc2bow(doc) for doc in corpus] #corpus

# %% [markdown]
# ## Test di diversi valori di k (num. di topics)

# %%
k_values = [5, 10, 15, 20, 25, 30, 40, 50, 75, 100, 150]
coherence_scores = []

for k in k_values:
    lda_model = LdaModel(corpus_bow, num_topics=k, id2word=dictionary)
    coherence_model = CoherenceModel(
        model=lda_model, texts=corpus, dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()
    coherence_scores.append(coherence_score)
    print(f"Number of topics: {k}, Coherence Score: {coherence_score}")
# Out:
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 5, Coherence Score: 0.5327923184901973
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 10, Coherence Score: 0.5505712676635153
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 15, Coherence Score: 0.5066349514708811
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 20, Coherence Score: 0.5107189274606843
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 25, Coherence Score: 0.486680646318408
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 30, Coherence Score: 0.47195789699598456
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 40, Coherence Score: 0.5031073857851694
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 50, Coherence Score: 0.48913005350232547
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 75, Coherence Score: 0.47162920386240814
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 100, Coherence Score: 0.4494521759781328
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/rossellaborra/lib/python3.8/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Number of topics: 150, Coherence Score: 0.4279430467067245

# %% [markdown]
# ## Stampa dei risultati

# %%
# Plot dei risultati
plt.plot(k_values, coherence_scores, marker='o')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score')
plt.title('Coherence Score vs. Number of Topics')
plt.show()
